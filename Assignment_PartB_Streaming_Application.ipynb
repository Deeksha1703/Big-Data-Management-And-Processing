# %% [markdown]
# # FIT3182 - Assignment 3
# ---
# ## Part B - Streaming Application
#
# - Filename: Assignment_PartB_Streaming_Application.ipynb
# - Student Name: Deeksha Sridhar
# - Student ID: 32187998

# %%
# !pip install pygeohash

# %%
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import pygeohash as pgh
import json
from pprint import pprint
from datetime import datetime

# Set up MongoDB connection
mongo_host = '192.168.86.244'
mongo_port = 27017
mongo_db_name = 'fit3182_assignment_db'
mongo_collection_name = 'streaming'

mongo_client = MongoClient(f'mongodb://{mongo_host}:{mongo_port}/')
mongo_db = mongo_client[mongo_db_name]
mongo_collection = mongo_db[mongo_collection_name]
mongo_collection.delete_many({})

# Set up Spark session
spark = SparkSession.builder.master('local[*]').appName('Spark Streaming from Kafka into MongoDB').getOrCreate()

# Set up Kafka connection
kafka_host = '192.168.86.244'
kafka_topic = 'streaming'

topic_stream_df = (
    spark.readStream.format('kafka')
    .option('kafka.bootstrap.servers', f'{kafka_host}:9092')
    .option('subscribe', kafka_topic)
    .load()
)

output_stream_df = topic_stream_df.select(col('value').alias('data'))

# Define batch processing function
def process_batch(batch_df, batch_id):
    raw_data = batch_df.collect()
    streams = [json.loads(item.asDict()['data']) for item in raw_data]
    hashMap = {}
    climateData = None
    
    for stream in streams:
        if stream['producer'] == 'climate_streaming':
            climateData = stream
        
        location = pgh.encode(stream['latitude'], stream['longitude'], precision=3)
        if location in hashMap:
            hashMap[location].append(stream)
        else:
            hashMap[location] = [stream]
    
    if climateData is not None:
        climateData['date'] = datetime.strptime(climateData['created_date'], '%d/%m/%Y')
        del climateData['created_date']
        
        climateLocation = pgh.encode(climateData['latitude'], climateData['longitude'], precision=3)
        
        if len(hashMap[climateLocation]) > 1:
            hotspots = {}
            
            for stream in hashMap[climateLocation]:
                producer = stream['producer']
                
                if producer != 'climate_streaming':
                    location = pgh.encode(stream['latitude'], stream['longitude'], precision=5) 
                    if location in hotspots:
                        hotspots[location].append(stream)
                    else:
                        hotspots[location] = [stream]
                        
            if climateData['air_temperature_celcius'] > 20 and climateData['GHI_w/m2'] > 180:
                fireCause = 'natural'
            else:
                fireCause = 'other'
            
            hotspotDocs = []
            
            for location in hotspots.keys():
                hotspotDoc = None
                totalSurfaceTemp = 0
                totalConfidence = 0
                numberOfData = 0
                
                for fire in hotspots[location]:
                    hotspotDoc = fire
                    totalSurfaceTemp += fire['surface_temperature_celcius']
                    totalConfidence += fire['confidence']
                    numberOfData += 1
                
                avgSurfaceTemp = int(totalSurfaceTemp / numberOfData)
                avgConfidence = int(totalConfidence / numberOfData)
                hotspotDoc['surface_temperature_celcius'] = avgSurfaceTemp
                hotspotDoc['confidence'] = avgConfidence
                
                curr_datetime = datetime.strptime(hotspotDoc['created_datetime'], '%d/%m/%Y %H:%M:%S')
                new_datetime = climateData['date'].replace(hour=curr_datetime.hour, minute=curr_datetime.minute)
                hotspotDoc['datetime'] = new_datetime.strftime('%d/%m/%Y %H:%M:%S')
                del hotspotDoc['created_datetime']
                
                hotspotDoc['cause'] = fireCause
                del hotspotDoc['producer']
                hotspotDocs.append(hotspotDoc)
    
            climateData['hotspots'] = hotspotDocs
    
    if climateData is not None:
        del climateData['producer']
        del climateData['latitude']
        del climateData['longitude']
        climateData['station'] = 948701
        pprint(climateData)
        mongo_collection.insert_one(climateData)

# Define streaming queries
db_writer = (
    output_stream_df
    .writeStream
    .outputMode('append')
    .trigger(processingTime='10 seconds') 
    .foreachBatch(process_batch) 
)

console_logger = (
    output_stream_df
    .writeStream
    .outputMode('append')
    .format('console')
)

# Start the streaming queries
writer_query = db_writer.start()
console_query = console_logger.start()

# Wait for termination or interruption
try:
    writer_query.awaitTermination()
    console_query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopped query')

# Stop the queries
writer_query.stop()
console_query.stop()
# Out:
# {'GHI_w/m2': 93,
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2023, 6, 12, 0, 0),
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 39.4,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 180,
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 6, 13, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 100,
#                'datetime': '13/06/2023 03:56:00',
#                'latitude': -36.5754,
#                'longitude': 142.2926,
#                'surface_temperature_celcius': 111},
#               {'cause': 'other',
#                'confidence': 82,
#                'datetime': '13/06/2023 08:44:00',
#                'latitude': -36.6995,
#                'longitude': 142.9146,
#                'surface_temperature_celcius': 56},
#               {'cause': 'other',
#                'confidence': 68,
#                'datetime': '13/06/2023 13:32:00',
#                'latitude': -37.8865,
#                'longitude': 143.3048,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 26.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 133,
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 6, 14, 0, 0),
#  'max_wind_speed': 16.9,
#  'precipitation': 0.16,
#  'precipitation_flag': 'G',
#  'relative_humidity': 53.6,
#  'station': 948701,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 6, 15, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 64,
#                'datetime': '15/06/2023 13:32:00',
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celcius': 32}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 56.8,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 90,
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2023, 6, 16, 0, 0),
#  'max_wind_speed': 12.0,
#  'precipitation': 0.39,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.1,
#  'station': 948701,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 75,
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2023, 6, 17, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 100,
#                'datetime': '17/06/2023 23:08:00',
#                'latitude': -36.4125,
#                'longitude': 143.1189,
#                'surface_temperature_celcius': 92}],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_flag': 'G',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 151,
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 6, 18, 0, 0),
#  'max_wind_speed': 12.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'relative_humidity': 58.7,
#  'station': 948701,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 139,
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 6, 19, 0, 0),
#  'max_wind_speed': 18.1,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 48.2,
#  'station': 948701,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 6, 20, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 59,
#                'datetime': '20/06/2023 18:20:00',
#                'latitude': -36.6463,
#                'longitude': 144.7594,
#                'surface_temperature_celcius': 41}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.63,
#  'precipitation_flag': 'G',
#  'relative_humidity': 59.7,
#  'station': 948701,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 178,
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 6, 21, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 64,
#                'datetime': '21/06/2023 03:56:00',
#                'latitude': -37.332,
#                'longitude': 143.375,
#                'surface_temperature_celcius': 46},
#               {'cause': 'other',
#                'confidence': 76,
#                'datetime': '21/06/2023 08:44:00',
#                'latitude': -37.7966,
#                'longitude': 142.3196,
#                'surface_temperature_celcius': 66},
#               {'cause': 'other',
#                'confidence': 92,
#                'datetime': '21/06/2023 13:32:00',
#                'latitude': -36.9396,
#                'longitude': 143.1462,
#                'surface_temperature_celcius': 70},
#               {'cause': 'other',
#                'confidence': 57,
#                'datetime': '21/06/2023 18:20:00',
#                'latitude': -37.8635,
#                'longitude': 143.1986,
#                'surface_temperature_celcius': 39}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 196,
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 6, 22, 0, 0),
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2023, 6, 23, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 78,
#                'datetime': '23/06/2023 23:08:00',
#                'latitude': -37.3226,
#                'longitude': 143.5442,
#                'surface_temperature_celcius': 51},
#               {'cause': 'other',
#                'confidence': 100,
#                'datetime': '23/06/2023 18:20:00',
#                'latitude': -37.9071,
#                'longitude': 143.538,
#                'surface_temperature_celcius': 88}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 90,
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2023, 6, 24, 0, 0),
#  'max_wind_speed': 15.9,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.7,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 6, 25, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 100,
#                'datetime': '25/06/2023 03:56:00',
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celcius': 65}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.6,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 105,
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2023, 6, 26, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 77,
#                'datetime': '26/06/2023 18:20:00',
#                'latitude': -36.1648,
#                'longitude': 143.3362,
#                'surface_temperature_celcius': 55}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 47.9,
#  'station': 948701,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 160,
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 6, 27, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 87,
#                'datetime': '27/06/2023 03:56:00',
#                'latitude': -36.1757,
#                'longitude': 145.7544,
#                'surface_temperature_celcius': 62}],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 57.7,
#  'station': 948701,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 6, 28, 0, 0),
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 138,
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 6, 29, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 79,
#                'datetime': '29/06/2023 23:08:00',
#                'latitude': -37.368,
#                'longitude': 148.05,
#                'surface_temperature_celcius': 53}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 41.2,
#  'station': 948701,
#  'windspeed_knots': 13.8}
# {'GHI_w/m2': 155,
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 6, 30, 0, 0),
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 49.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 107,
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2023, 7, 1, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 56,
#                'datetime': '01/07/2023 23:08:00',
#                'latitude': -37.4421,
#                'longitude': 148.259,
#                'surface_temperature_celcius': 39}],
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.7,
#  'station': 948701,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 114,
#  'air_temperature_celcius': 13,
#  'date': datetime.datetime(2023, 7, 2, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 71,
#                'datetime': '02/07/2023 03:56:00',
#                'latitude': -37.522,
#                'longitude': 143.3874,
#                'surface_temperature_celcius': 73},
#               {'cause': 'other',
#                'confidence': 90,
#                'datetime': '02/07/2023 03:56:00',
#                'latitude': -37.331,
#                'longitude': 143.122,
#                'surface_temperature_celcius': 65}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'relative_humidity': 47.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 110,
#  'air_temperature_celcius': 13,
#  'date': datetime.datetime(2023, 7, 3, 0, 0),
#  'max_wind_speed': 13.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 194,
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'hotspots': [{'cause': 'natural',
#                'confidence': 74,
#                'datetime': '04/07/2023 08:44:00',
#                'latitude': -36.7904,
#                'longitude': 141.7938,
#                'surface_temperature_celcius': 48},
#               {'cause': 'natural',
#                'confidence': 100,
#                'datetime': '04/07/2023 23:08:00',
#                'latitude': -37.0761,
#                'longitude': 141.0574,
#                'surface_temperature_celcius': 89}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 46.8,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 196,
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 7, 5, 0, 0),
#  'hotspots': [{'cause': 'natural',
#                'confidence': 84,
#                'datetime': '05/07/2023 03:56:00',
#                'latitude': -36.0325,
#                'longitude': 145.7562,
#                'surface_temperature_celcius': 58}],
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.4,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 163,
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 7, 6, 0, 0),
#  'max_wind_speed': 15.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 55.8,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 178,
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 7, 7, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 67,
#                'datetime': '07/07/2023 03:56:00',
#                'latitude': -35.4625,
#                'longitude': 143.1486,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 57.0,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 82,
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2023, 7, 8, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 73,
#                'datetime': '08/07/2023 13:32:00',
#                'latitude': -37.561,
#                'longitude': 148.032,
#                'surface_temperature_celcius': 34}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 42.9,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 107,
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2023, 7, 9, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 73,
#                'datetime': '09/07/2023 23:08:00',
#                'latitude': -37.0228,
#                'longitude': 148.1996,
#                'surface_temperature_celcius': 52}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.9,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 134,
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 7, 10, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 99,
#                'datetime': '10/07/2023 23:08:00',
#                'latitude': -37.609,
#                'longitude': 149.32,
#                'surface_temperature_celcius': 84}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'relative_humidity': 44.6,
#  'station': 948701,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2023, 7, 11, 0, 0),
#  'hotspots': [{'cause': 'natural',
#                'confidence': 89,
#                'datetime': '11/07/2023 13:32:00',
#                'latitude': -35.4255,
#                'longitude': 143.6306,
#                'surface_temperature_celcius': 65}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'relative_humidity': 61.0,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 153,
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 7, 12, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 75,
#                'datetime': '12/07/2023 08:44:00',
#                'latitude': -37.4621,
#                'longitude': 143.0869,
#                'surface_temperature_celcius': 48},
#               {'cause': 'other',
#                'confidence': 79,
#                'datetime': '12/07/2023 13:32:00',
#                'latitude': -36.8691,
#                'longitude': 142.7205,
#                'surface_temperature_celcius': 53},
#               {'cause': 'other',
#                'confidence': 76,
#                'datetime': '12/07/2023 13:32:00',
#                'latitude': -37.228,
#                'longitude': 142.146,
#                'surface_temperature_celcius': 42},
#               {'cause': 'other',
#                'confidence': 67,
#                'datetime': '12/07/2023 18:20:00',
#                'latitude': -36.6228,
#                'longitude': 142.428,
#                'surface_temperature_celcius': 43}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 147,
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 7, 13, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 66,
#                'datetime': '13/07/2023 18:20:00',
#                'latitude': -37.5358,
#                'longitude': 143.0572,
#                'surface_temperature_celcius': 43}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.63,
#  'precipitation_flag': 'G',
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 82,
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2023, 7, 14, 0, 0),
#  'max_wind_speed': 9.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 42.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 159,
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 7, 15, 0, 0),
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 147,
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 7, 16, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 95,
#                'datetime': '16/07/2023 08:44:00',
#                'latitude': -37.8906,
#                'longitude': 146.2035,
#                'surface_temperature_celcius': 75}],
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 7, 17, 0, 0),
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'relative_humidity': 53.8,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 93,
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2023, 7, 18, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 64,
#                'datetime': '18/07/2023 13:32:00',
#                'latitude': -37.46,
#                'longitude': 148.113,
#                'surface_temperature_celcius': 52}],
#  'max_wind_speed': 16.9,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'relative_humidity': 39.9,
#  'station': 948701,
#  'windspeed_knots': 12.6}
# {'GHI_w/m2': 112,
#  'air_temperature_celcius': 13,
#  'date': datetime.datetime(2023, 7, 19, 0, 0),
#  'max_wind_speed': 9.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'relative_humidity': 49.4,
#  'station': 948701,
#  'windspeed_knots': 3.8}
# {'GHI_w/m2': 147,
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 7, 20, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 96,
#                'datetime': '20/07/2023 03:56:00',
#                'latitude': -37.6622,
#                'longitude': 142.1001,
#                'surface_temperature_celcius': 79},
#               {'cause': 'other',
#                'confidence': 82,
#                'datetime': '20/07/2023 13:32:00',
#                'latitude': -36.8299,
#                'longitude': 142.2781,
#                'surface_temperature_celcius': 56}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.63,
#  'precipitation_flag': 'G',
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 111,
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2023, 7, 21, 0, 0),
#  'hotspots': [{'cause': 'other',
#                'confidence': 64,
#                'datetime': '21/07/2023 03:56:00',
#                'latitude': -37.46,
#                'longitude': 148.113,
#                'surface_temperature_celcius': 52}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 16.7}
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/conda/lib/python3.8/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# Interrupted by CTRL-C. Stopped query
