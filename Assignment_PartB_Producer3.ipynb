# %% [markdown]
# # FIT3182 - Assignment 3
# ---
# ## Part B - Producer 3
#
# - Filename: Assignment_PartB_Producer3.ipynb
# - Student Name: Deeksha Sridhar
# - Student ID: 32187998

# %%
import pymongo
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random


def read_hotspot_TERRA_streaming():
    """
    Read the hotspot TERRA streaming data from the CSV file and preprocess it.
    Returns:
        list: List of dictionaries containing the preprocessed hotspot TERRA data.
    """
    hotspot_TERRA_streaming = pd.read_csv('hotspot_TERRA_streaming.csv')

    data = []
    for index, terra_row in hotspot_TERRA_streaming.iterrows():
        document = {}
        document['latitude'] = float(terra_row['latitude'])
        document['longitude'] = float(terra_row['longitude'])
        document['confidence'] = int(terra_row['confidence'])
        document['surface_temperature_celcius'] = int(terra_row['surface_temperature_celcius'])
        data.append(document)

    return data


def get_latest_date():
    """
    Get the latest date from the collection.
    Returns:
        datetime: The latest date in the collection or current datetime if collection is empty.
    """
    latest_date = collection.aggregate([
        {"$sort": {"date": -1}},
        {"$project": {"_id": 0, "date": 1}},
        {"$limit": 1}
    ])
    for document in latest_date:
        latest_date = document['date']
        break
    else:
        latest_date = datetime.now()  

    return latest_date


def publish_message(producer_instance, topic_name, data):
    """
    Publishes a message to the Kafka topic.
    Args:
        producer_instance (KafkaProducer): The Kafka producer instance.
        topic_name (str): Name of the Kafka topic.
        data (dict): Data to be published.
    """
    try:
        producer_instance.send(topic_name, value=data)
        print('Message published successfully. ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))


def connect_kafka_producer():
    """
    Connects to the Kafka server and creates a Kafka producer instance.
    Returns:
        KafkaProducer: The Kafka producer instance.
    """
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['192.168.86.244:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting to Kafka.')
        print(str(ex))
    finally:
        return _producer


if __name__ == '__main__':
    topic = 'streaming'
    producer = connect_kafka_producer()
    data = read_hotspot_TERRA_streaming()
    latest_date = get_latest_date() + timedelta(days=1)
    seconds_passed = 0

    while True:
        chosen_data = random.choice(data)
        curr_date = latest_date + timedelta(seconds=seconds_passed)
        chosen_data['producer'] = "hotspot_TERRA_streaming"
        chosen_data["created_datetime"] = curr_date.strftime("%d/%m/%Y %H:%M:%S")
        publish_message(producer, topic, chosen_data)
        seconds_passed += 17280
        sleep(2)
# Out:
# Message published successfully. {'latitude': -36.601, 'longitude': 144.6378, 'confidence': 97, 'surface_temperature_celcius': 80, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2023 00:00:00'}
# Message published successfully. {'latitude': -37.7943, 'longitude': 143.0545, 'confidence': 70, 'surface_temperature_celcius': 45, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2023 04:48:00'}
# Message published successfully. {'latitude': -36.4837, 'longitude': 142.6042, 'confidence': 83, 'surface_temperature_celcius': 63, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2023 09:36:00'}
# Message published successfully. {'latitude': -36.5233, 'longitude': 146.7436, 'confidence': 63, 'surface_temperature_celcius': 42, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2023 14:24:00'}
# Message published successfully. {'latitude': -37.8387, 'longitude': 144.6301, 'confidence': 53, 'surface_temperature_celcius': 39, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/01/2023 19:12:00'}
# Message published successfully. {'latitude': -37.4737, 'longitude': 145.6985, 'confidence': 67, 'surface_temperature_celcius': 43, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '03/01/2023 00:00:00'}
# Message published successfully. {'latitude': -36
 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '29/01/2023 00:00:00'}
# Message published successfully. {'latitude': -36.5134, 'longitude': 142.4682, 'confidence': 70, 'surface_temperature_celcius': 53, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '29/01/2023 04:48:00'}
# Message published successfully. {'latitude': -36.241, 'longitude': 143.1229, 'confidence': 75, 'surface_temperature_celcius': 53, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '29/01/2023 09:36:00'}
# Message published successfully. {'latitude': -36.3863, 'longitude': 143.339, 'confidence': 82, 'surface_temperature_celcius': 62, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '29/01/2023 14:24:00'}
# Message published successfully. {'latitude': -36.152, 'longitude': 143.578, 'confidence': 69, 'surface_temperature_celcius': 44, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '29/01/2023 19:12:00'}
# Message published successfully. {'latitude': -37.9754, 'longitude': 143.3964, 'confidence': 83, 'surface_temperature_celcius': 57, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '30/01/2023 00:00:00'}
# Message published successfully. {'latitude': -37.5358, 'longitude': 143.0572, 'confidence': 66, 'surface_temperature_celcius': 43, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '30/01/2023 04:48:00'}
# Message published successfully. {'latitude': -35.7768, 'longitude': 143.4803, 'confidence': 84, 'surface_temperature_celcius': 58, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '30/01/2023 09:36:00'}
# Message published successfully. {'latitude': -35.2464, 'longitude': 141.1143, 'confidence': 98, 'surface_temperature_celcius': 45, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '30/01/2023 14:24:00'}
# Message published successfully. {'latitude': -38.3557, 'longitude': 147.0372, 'confidence': 78, 'surface_temperature_celcius': 52, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '30/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.3387, 'longitude': 141.7542, 'confidence': 96, 'surface_temperature_celcius': 77, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '31/01/2023 00:00:00'}
# Message published successfully. {'latitude': -35.9839, 'longitude': 143.6719, 'confidence': 57, 'surface_temperature_celcius': 47, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '31/01/2023 04:48:00'}
# Message published successfully. {'latitude': -37.6073, 'longitude': 142.8819, 'confidence': 83, 'surface_temperature_celcius': 57, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '31/01/2023 09:36:00'}
# Message published successfully. {'latitude': -36.9364, 'longitude': 143.4996, 'confidence': 92, 'surface_temperature_celcius': 70, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '31/01/2023 14:24:00'}
# Message published successfully. {'latitude': -37.4439, 'longitude': 142.9811, 'confidence': 71, 'surface_temperature_celcius': 46, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '31/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.4142, 'longitude': 143.1077, 'confidence': 100, 'surface_temperature_celcius': 97, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/02/2023 00:00:00'}
# Message published successfully. {'latitude': -36.2205, 'longitude': 141.7933, 'confidence': 81, 'surface_temperature_celcius': 54, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/02/2023 04:48:00'}
# Message published successfully. {'latitude': -37.6964, 'longitude': 142.8583, 'confidence': 91, 'surface_temperature_celcius': 69, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/02/2023 09:36:00'}
# Message published successfully. {'latitude': -36.7806, 'longitude': 141.5597, 'confidence': 94, 'surface_temperature_celcius': 74, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/02/2023 14:24:00'}
# Message published successfully. {'latitude': -37.5742, 'longitude': 144.7536, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '01/02/2023 19:12:00'}
# Message published successfully. {'latitude': -37.554, 'longitude': 148.073, 'confidence': 63, 'surface_temperature_celcius': 37, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/02/2023 00:00:00'}
# Message published successfully. {'latitude': -36.398, 'longitude': 145.286, 'confidence': 65, 'surface_temperature_celcius': 39, 'producer': 'hotspot_TERRA_streaming', 'created_datetime': '02/02/2023 04:48:00'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 100
#      98 publish_message(producer, topic, chosen_data)
#      99 seconds_passed += 17280
# --> 100 sleep(2)
#
# KeyboardInterrupt:
