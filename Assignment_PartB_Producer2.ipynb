# %% [markdown]
# # FIT3182 - Assignment 3
# ---
# ## Part B - Producer 2
#
# - Filename: Assignment_PartB_Producer2.ipynb
# - Student Name: Deeksha Sridhar
# - Student ID: 32187998

# %%
import pymongo
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random


def read_hotspot_AQUA_streaming():
    """
    Read the hotspot AQUA streaming data from the CSV file and preprocess it.
    Returns:
        list: List of dictionaries containing the preprocessed hotspot AQUA data.
    """
    hotspot_AQUA_streaming = pd.read_csv('hotspot_AQUA_streaming.csv')

    data = []
    for index, aqua_row in hotspot_AQUA_streaming.iterrows():
        document = {}
        document['latitude'] = float(aqua_row['latitude'])
        document['longitude'] = float(aqua_row['longitude'])
        document['confidence'] = int(aqua_row['confidence'])
        document['surface_temperature_celcius'] = int(aqua_row['surface_temperature_celcius'])
        data.append(document)

    return data


def get_latest_date():
    """
    Get the latest date from the collection.
    Returns:
        datetime: The latest date in the collection or current datetime if collection is empty.
    """
    latest_date = collection.aggregate([
        {"$sort": {"date": -1}},
        {"$project": {"_id": 0, "date": 1}},
        {"$limit": 1}
    ])
    for document in latest_date:
        latest_date = document['date']
        break
    else:
        latest_date = datetime.now() 

    return latest_date


def publish_message(producer_instance, topic_name, data):
    """
    Publishes a message to the Kafka topic.
    Args:
        producer_instance (KafkaProducer): The Kafka producer instance.
        topic_name (str): Name of the Kafka topic.
        data (dict): Data to be published.
    """
    try:
        producer_instance.send(topic_name, value=data)
        print('Message published successfully. ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))


def connect_kafka_producer():
    """
    Connects to the Kafka server and creates a Kafka producer instance.
    Returns:
        KafkaProducer: The Kafka producer instance.
    """
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['192.168.86.244:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting to Kafka.')
        print(str(ex))
    finally:
        return _producer


if __name__ == '__main__':
    topic = 'streaming'
    producer = connect_kafka_producer()
    data = read_hotspot_AQUA_streaming()
    latest_date = get_latest_date() + timedelta(days=1)
    seconds_passed = 0

    while True:
        chosen_data = random.choice(data)
        curr_date = latest_date + timedelta(seconds=seconds_passed)
        chosen_data['producer'] = "hotspot_AQUA_streaming"
        chosen_data["created_datetime"] = curr_date.strftime("%d/%m/%Y %H:%M:%S")
        publish_message(producer, topic, chosen_data)
        seconds_passed += 17280
        sleep(2)
# Out:
# Message published successfully. {'latitude': -37.9913, 'longitude': 143.5272, 'confidence': 64, 'surface_temperature_celcius': 42, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2023 00:00:00'}
# Message published successfully. {'latitude': -37.2341, 'longitude': 149.1736, 'confidence': 80, 'surface_temperature_celcius': 53, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2023 04:48:00'}
# Message published successfully. {'latitude': -37.585, 'longitude': 149.336, 'confidence': 100, 'surface_temperature_celcius': 54, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2023 09:36:00'}
# Message published successfully. {'latitude': -37.34, 'longitude': 143.123, 'confidence': 81, 'surface_temperature_celcius': 56, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2023 14:24:00'}
# Message published successfully. {'latitude': -37.4368, 'longitude': 149.1191, 'confidence': 56, 'surface_temperature_celcius': 52, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.0189, 'longitude': 145.6844, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '03/01/2023 00:00:00'}
# Message published successfully. {'latitude': -38.0392, 'longitude': 143.8842, 'confidence': 66, 'surface_temperature_celcius': 45, 'producer': 'hotspot_AQUA_streaming', 'created_datetime':
 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '27/01/2023 19:12:00'}
# Message published successfully. {'latitude': -38.0398, 'longitude': 142.6159, 'confidence': 87, 'surface_temperature_celcius': 62, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '28/01/2023 00:00:00'}
# Message published successfully. {'latitude': -36.3268, 'longitude': 142.3643, 'confidence': 53, 'surface_temperature_celcius': 38, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '28/01/2023 04:48:00'}
# Message published successfully. {'latitude': -37.4854, 'longitude': 145.7008, 'confidence': 64, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '28/01/2023 09:36:00'}
# Message published successfully. {'latitude': -36.6217, 'longitude': 145.2537, 'confidence': 75, 'surface_temperature_celcius': 49, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '28/01/2023 14:24:00'}
# Message published successfully. {'latitude': -36.6999, 'longitude': 141.6955, 'confidence': 79, 'surface_temperature_celcius': 52, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '28/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.6999, 'longitude': 141.6955, 'confidence': 79, 'surface_temperature_celcius': 52, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '29/01/2023 00:00:00'}
# Message published successfully. {'latitude': -37.0682, 'longitude': 145.3607, 'confidence': 81, 'surface_temperature_celcius': 55, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '29/01/2023 04:48:00'}
# Message published successfully. {'latitude': -36.7159, 'longitude': 141.4716, 'confidence': 51, 'surface_temperature_celcius': 38, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '29/01/2023 09:36:00'}
# Message published successfully. {'latitude': -37.223, 'longitude': 147.9431, 'confidence': 100, 'surface_temperature_celcius': 105, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '29/01/2023 14:24:00'}
# Message published successfully. {'latitude': -38.219, 'longitude': 143.7352, 'confidence': 68, 'surface_temperature_celcius': 44, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '29/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.0723, 'longitude': 141.3605, 'confidence': 72, 'surface_temperature_celcius': 46, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '30/01/2023 00:00:00'}
# Message published successfully. {'latitude': -36.4339, 'longitude': 141.5458, 'confidence': 87, 'surface_temperature_celcius': 62, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '30/01/2023 04:48:00'}
# Message published successfully. {'latitude': -38.038, 'longitude': 142.986, 'confidence': 65, 'surface_temperature_celcius': 40, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '30/01/2023 09:36:00'}
# Message published successfully. {'latitude': -36.779, 'longitude': 146.108, 'confidence': 61, 'surface_temperature_celcius': 32, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '30/01/2023 14:24:00'}
# Message published successfully. {'latitude': -37.7943, 'longitude': 143.0545, 'confidence': 70, 'surface_temperature_celcius': 45, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '30/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.4179, 'longitude': 144.2924, 'confidence': 94, 'surface_temperature_celcius': 75, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '31/01/2023 00:00:00'}
# Message published successfully. {'latitude': -37.6069, 'longitude': 141.4724, 'confidence': 58, 'surface_temperature_celcius': 40, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '31/01/2023 04:48:00'}
# Message published successfully. {'latitude': -37.8114, 'longitude': 143.1827, 'confidence': 81, 'surface_temperature_celcius': 54, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '31/01/2023 09:36:00'}
# Message published successfully. {'latitude': -37.2162, 'longitude': 146.2408, 'confidence': 76, 'surface_temperature_celcius': 38, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '31/01/2023 14:24:00'}
# Message published successfully. {'latitude': -35.0917, 'longitude': 141.1508, 'confidence': 77, 'surface_temperature_celcius': 50, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '31/01/2023 19:12:00'}
# Message published successfully. {'latitude': -36.2756, 'longitude': 145.811, 'confidence': 50, 'surface_temperature_celcius': 39, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/02/2023 00:00:00'}
# Message published successfully. {'latitude': -38.1868, 'longitude': 143.0938, 'confidence': 70, 'surface_temperature_celcius': 45, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/02/2023 04:48:00'}
# Message published successfully. {'latitude': -38.1756, 'longitude': 143.9829, 'confidence': 65, 'surface_temperature_celcius': 53, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/02/2023 09:36:00'}
# Message published successfully. {'latitude': -36.6936, 'longitude': 145.2788, 'confidence': 86, 'surface_temperature_celcius': 61, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/02/2023 14:24:00'}
# Message published successfully. {'latitude': -37.3493, 'longitude': 149.3691, 'confidence': 66, 'surface_temperature_celcius': 80, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '01/02/2023 19:12:00'}
# Message published successfully. {'latitude': -35.7786, 'longitude': 143.469, 'confidence': 84, 'surface_temperature_celcius': 58, 'producer': 'hotspot_AQUA_streaming', 'created_datetime': '02/02/2023 00:00:00'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 100
#      98 publish_message(producer, topic, chosen_data)
#      99 seconds_passed += 17280
# --> 100 sleep(2)
#
# KeyboardInterrupt:
